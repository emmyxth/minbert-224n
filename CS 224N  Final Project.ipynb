# %% [markdown]
# # minBERT

# %% [markdown]
# ## 1. Upload your files

# %% [markdown]
# ### Option 1: Upload your files to your Google Drive, and mount the drive
# You can upload your files to your own Google drive. This is the ''safest'' way to set up the Colab, since your files are stored in your Google Drive instead of the Colab Runtime, which may terminate if you leave it on for too long (~8 hours, or if you put your laptop to sleep mode) and lose your files.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Relocate to your code directory

# %%
# %cd /content/drive/MyDrive/minbert-224n/
! ls # verify that you are in the right directory
# Out:
# /content/drive/MyDrive/minbert-224n
#  base_bert.py			 ids-cfimdb-test-out.csv   README.md
#  baselinecheck.sh		 ids-sst-dev-out.csv	   sanity_check.data
#  bert.py			 ids-sst-test-out.csv	   sanity_check.py
#  cfimdb-classifier.pt		 LICENSE		   scripts
#  classifier.py			 multitask_classifier.py   setup.sh
#  config.py			 optimizer.py		   sst-classifier.pt
# 'CS 224N  Final Project.ipynb'	 optimizer_test.npy	   STRUCTURE.md
#  data				 optimizer_test.py	   tokenizer.py
#  datasets.py			 predictions		   utils.py
#  evaluation.py			 prepare_submit.py
#  ids-cfimdb-dev-out.csv		 __pycache__

# %% [markdown]
# ## 3. Run scripts

# %% [markdown]
# To run on GPU, please make sure your runtime type is using the GPU accelerator! To do so, click on:
#
# ![colab1.PNG](data:image/png;base64,...)
#
# on the upper-right hand corner, then click "Change runtime type" in the bottom-left of the popped-up panel, then select "GPU" as your hardware accelerator.

# %% [markdown]
# Now you can directly run the commands specified by the assignment files in the following code blocks.

# %% [markdown]
# imports

# %%
! bash setup.sh
# Out:
# setup.sh: line 3: conda: command not found
# setup.sh: line 4: conda: command not found
# setup.sh: line 5: conda: command not found
# setup.sh: line 7: conda: command not found
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tqdm==4.58.0
#   Downloading tqdm-4.58.0-py2.py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 KB 6.1 MB/s eta 0:00:00
# Installing collected packages: tqdm
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
# Successfully installed tqdm-4.58.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests==2.25.1 in /usr/local/lib/python3.8/dist-packages (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests==2.25.1) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests==2.25.1) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests==2.25.1) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests==2.25.1) (2.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting importlib-metadata==3.7.0
#   Downloading importlib_metadata-3.7.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata==3.7.0) (3.14.0)
# Installing collected packages: importlib-metadata
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.0.0
#     Uninstalling importlib-metadata-6.0.0:
#       Successfully uninstalled importlib-metadata-6.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# markdown 3.4.1 requires importlib-metadata>=4.4; python_version < "3.10", but you have importlib-metadata 3.7.0 which is incompatible.
# gym 0.25.2 requires importlib-metadata>=4.8.0; python_version < "3.10", but you have importlib-metadata 3.7.0 which is incompatible.
# Successfully installed importlib-metadata-3.7.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting filelock==3.0.12
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Installing collected packages: filelock
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.9.0
#     Uninstalling filelock-3.9.0:
#       Successfully uninstalled filelock-3.9.0
# Successfully installed filelock-3.0.12
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sklearn==0.0
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from sklearn==0.0) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->sklearn==0.0) (1.2.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->sklearn==0.0) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->sklearn==0.0) (3.1.0)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->sklearn==0.0) (1.22.4)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=9b15abe5ca2ee7aaad295296436e468edf5ec09e907a44f1727c4b9795fc66e0
#   Stored in directory: /root/.cache/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tokenizers==0.10.1
#   Downloading tokenizers-0.10.1-cp38-cp38-manylinux2010_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 50.5 MB/s eta 0:00:00
# Installing collected packages: tokenizers
# Successfully installed tokenizers-0.10.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting explainaboard_client==0.0.7
#   Downloading explainaboard_client-0.0.7-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from explainaboard_client==0.0.7) (4.58.0)
# Collecting explainaboard-api-client>=0.2.0
#   Downloading explainaboard_api_client-0.2.26-py2.py3-none-any.whl (186 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.3/186.3 KB 11.7 MB/s eta 0:00:00
# Collecting urllib3>=1.25.3
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from explainaboard-api-client>=0.2.0->explainaboard_client==0.0.7) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil->explainaboard-api-client>=0.2.0->explainaboard_client==0.0.7) (1.15.0)
# Installing collected packages: urllib3, explainaboard-api-client, explainaboard_client
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed explainaboard-api-client-0.2.26 explainaboard_client-0.0.7 urllib3-1.26.14

# %% [markdown]
# baseline check.

# %%
! bash scripts/baselinecheck.sh
# Out:
# Training Sentiment Classifier on SST...
# load 8544 data from data/ids-sst-train.csv
# load 1101 data from data/ids-sst-dev.csv
# Downloading: 100% 232k/232k [00:00<00:00, 679kB/s]
# Downloading: 100% 570/570 [00:00<00:00, 618kB/s]
# Downloading: 100% 440M/440M [00:05<00:00, 86.7MB/s]
# train-0: 100% 1068/1068 [00:27<00:00, 39.31it/s]
# eval: 100% 1068/1068 [00:24<00:00, 43.38it/s]
# eval: 100% 138/138 [00:03<00:00, 45.87it/s]
# save the model to sst-classifier.pt
# Epoch 0: train loss :: 1.586, train acc :: 0.387, dev acc :: 0.369
# train-1: 100% 1068/1068 [00:25<00:00, 42.24it/s]
# eval: 100% 1068/1068 [00:24<00:00, 43.33it/s]
# eval: 100% 138/138 [00:02<00:00, 46.84it/s]
# save the model to sst-classifier.pt
# Epoch 1: train loss :: 1.536, train acc :: 0.404, dev acc :: 0.377
# train-2: 100% 1068/1068 [00:26<00:00, 41.00it/s]
# eval: 100% 1068/1068 [00:24<00:00, 43.95it/s]
# eval: 100% 138/138 [00:02<00:00, 46.54it/s]
# Epoch 2: train loss :: 1.505, train acc :: 0.328, dev acc :: 0.305
# train-3: 100% 1068/1068 [00:24<00:00, 43.53it/s]
# eval: 100% 1068/1068 [00:23<00:00, 44.77it/s]
# eval: 100% 138/138 [00:03<00:00, 41.70it/s]
# Epoch 3: train loss :: 1.491, train acc :: 0.342, dev acc :: 0.312
# train-4: 100% 1068/1068 [00:24<00:00, 44.09it/s]
# eval: 100% 1068/1068 [00:24<00:00, 44.12it/s]
# eval: 100% 138/138 [00:02<00:00, 46.83it/s]
# Epoch 4: train loss :: 1.482, train acc :: 0.323, dev acc :: 0.319
# train-5: 100% 1068/1068 [00:24<00:00, 43.28it/s]
# eval: 100% 1068/1068 [00:24<00:00, 44.01it/s]
# eval: 100% 138/138 [00:02<00:00, 46.95it/s]
# Epoch 5: train loss :: 1.476, train acc :: 0.363, dev acc :: 0.347
# train-6: 100% 1068/1068 [00:24<00:00, 43.42it/s]
# eval: 100% 1068/1068 [00:23<00:00, 44.71it/s]
# eval: 100% 138/138 [00:03<00:00, 42.60it/s]
# Epoch 6: train loss :: 1.465, train acc :: 0.389, dev acc :: 0.375
# train-7: 100% 1068/1068 [00:24<00:00, 43.51it/s]
# eval: 100% 1068/1068 [00:24<00:00, 44.03it/s]
# eval: 100% 138/138 [00:02<00:00, 46.89it/s]
# save the model to sst-classifier.pt
# Epoch 7: train loss :: 1.479, train acc :: 0.432, dev acc :: 0.409
# train-8: 100% 1068/1068 [00:25<00:00, 41.70it/s]
# eval: 100% 1068/1068 [00:24<00:00, 43.86it/s]
# eval: 100% 138/138 [00:02<00:00, 46.94it/s]
# Epoch 8: train loss :: 1.465, train acc :: 0.320, dev acc :: 0.297
# train-9: 100% 1068/1068 [00:24<00:00, 43.46it/s]
# eval: 100% 1068/1068 [00:24<00:00, 44.24it/s]
# eval: 100% 138/138 [00:03<00:00, 45.03it/s]
# Epoch 9: train loss :: 1.473, train acc :: 0.393, dev acc :: 0.373
# Evaluating on SST...
# load model from sst-classifier.pt
# load 1101 data from data/ids-sst-dev.csv
# eval: 100% 138/138 [00:03<00:00, 44.92it/s]
# DONE DEV
# eval: 100% 277/277 [00:06<00:00, 43.64it/s]
# DONE Test
# dev acc :: 0.409
# Training Sentiment Classifier on cfimdb...
# load 1707 data from data/ids-cfimdb-train.csv
# load 245 data from data/ids-cfimdb-dev.csv
# train-0: 100% 214/214 [00:43<00:00,  4.97it/s]
# eval: 100% 214/214 [00:42<00:00,  5.04it/s]
# eval: 100% 31/31 [00:06<00:00,  4.74it/s]
# save the model to cfimdb-classifier.pt
# Epoch 0: train loss :: 0.730, train acc :: 0.507, dev acc :: 0.522
# train-1: 100% 214/214 [00:43<00:00,  4.90it/s]
# eval: 100% 214/214 [00:42<00:00,  5.07it/s]
# eval: 100% 31/31 [00:05<00:00,  5.18it/s]
# save the model to cfimdb-classifier.pt
# Epoch 1: train loss :: 0.678, train acc :: 0.703, dev acc :: 0.722
# train-2: 100% 214/214 [00:43<00:00,  4.92it/s]
# eval: 100% 214/214 [00:42<00:00,  4.99it/s]
# eval: 100% 31/31 [00:06<00:00,  5.16it/s]
# Epoch 2: train loss :: 0.650, train acc :: 0.642, dev acc :: 0.633
# train-3: 100% 214/214 [00:43<00:00,  4.92it/s]
# eval: 100% 214/214 [00:42<00:00,  4.99it/s]
# eval: 100% 31/31 [00:06<00:00,  4.97it/s]
# save the model to cfimdb-classifier.pt
# Epoch 3: train loss :: 0.635, train acc :: 0.714, dev acc :: 0.731
# train-4: 100% 214/214 [00:42<00:00,  5.02it/s]
# eval: 100% 214/214 [00:42<00:00,  5.01it/s]
# eval: 100% 31/31 [00:05<00:00,  5.18it/s]
# Epoch 4: train loss :: 0.623, train acc :: 0.728, dev acc :: 0.722
# train-5: 100% 214/214 [00:43<00:00,  4.95it/s]
# eval: 100% 214/214 [00:42<00:00,  5.04it/s]
# eval: 100% 31/31 [00:06<00:00,  4.97it/s]
# Epoch 5: train loss :: 0.611, train acc :: 0.747, dev acc :: 0.710
# train-6: 100% 214/214 [00:43<00:00,  4.96it/s]
# eval: 100% 214/214 [00:42<00:00,  5.04it/s]
# eval: 100% 31/31 [00:06<00:00,  5.01it/s]
# save the model to cfimdb-classifier.pt
# Epoch 6: train loss :: 0.610, train acc :: 0.752, dev acc :: 0.735
# train-7: 100% 214/214 [00:43<00:00,  4.93it/s]
# eval: 100% 214/214 [00:42<00:00,  5.07it/s]
# eval: 100% 31/31 [00:05<00:00,  5.18it/s]
# Epoch 7: train loss :: 0.614, train acc :: 0.689, dev acc :: 0.702
# train-8: 100% 214/214 [00:43<00:00,  4.92it/s]
# eval: 100% 214/214 [00:42<00:00,  4.99it/s]
# eval: 100% 31/31 [00:06<00:00,  4.91it/s]
# save the model to cfimdb-classifier.pt
# Epoch 8: train loss :: 0.588, train acc :: 0.751, dev acc :: 0.759
# train-9: 100% 214/214 [00:43<00:00,  4.96it/s]
# eval: 100% 214/214 [00:42<00:00,  5.03it/s]
# eval: 100% 31/31 [00:06<00:00,  4.88it/s]
# Epoch 9: train loss :: 0.604, train acc :: 0.693, dev acc :: 0.649
# Evaluating on cfimdb...
# load model from cfimdb-classifier.pt
# load 245 data from data/ids-cfimdb-dev.csv
# eval: 100% 31/31 [00:06<00:00,  5.10it/s]
# DONE DEV
# eval: 100% 61/61 [00:12<00:00,  4.87it/s]
# DONE Test
# dev acc :: 0.759
# Training Sentiment Classifier on SST...
# load 8544 data from data/ids-sst-train.csv
# load 1101 data from data/ids-sst-dev.csv
# train-0: 100% 1068/1068 [02:12<00:00,  8.09it/s]
# eval: 100% 1068/1068 [00:24<00:00, 42.81it/s]
# eval: 100% 138/138 [00:03<00:00, 42.93it/s]
# save the model to sst-classifier.pt
# Epoch 0: train loss :: 1.268, train acc :: 0.588, dev acc :: 0.490
# train-1: 100% 1068/1068 [02:12<00:00,  8.08it/s]
# eval: 100% 1068/1068 [00:25<00:00, 41.49it/s]
# eval: 100% 138/138 [00:03<00:00, 45.83it/s]
# save the model to sst-classifier.pt
# Epoch 1: train loss :: 0.960, train acc :: 0.753, dev acc :: 0.525
# train-2: 100% 1068/1068 [02:12<00:00,  8.09it/s]
# eval: 100% 1068/1068 [00:24<00:00, 42.93it/s]
# eval: 100% 138/138 [00:03<00:00, 43.93it/s]
# Epoch 2: train loss :: 0.720, train acc :: 0.871, dev acc :: 0.519
# train-3: 100% 1068/1068 [02:10<00:00,  8.19it/s]
# eval: 100% 1068/1068 [00:24<00:00, 42.90it/s]
# eval: 100% 138/138 [00:02<00:00, 46.04it/s]
# Epoch 3: train loss :: 0.494, train acc :: 0.900, dev acc :: 0.500
# train-4: 100% 1068/1068 [02:10<00:00,  8.20it/s]
# eval: 100% 1068/1068 [00:24<00:00, 42.98it/s]
# eval: 100% 138/138 [00:03<00:00, 45.76it/s]
# Epoch 4: train loss :: 0.316, train acc :: 0.961, dev acc :: 0.509
# train-5: 100% 1068/1068 [02:10<00:00,  8.16it/s]
# eval: 100% 1068/1068 [00:24<00:00, 43.50it/s]
# eval: 100% 138/138 [00:03<00:00, 37.88it/s]
# Epoch 5: train loss :: 0.209, train acc :: 0.968, dev acc :: 0.500
# train-6: 100% 1068/1068 [02:10<00:00,  8.19it/s]
# eval: 100% 1068/1068 [00:25<00:00, 42.60it/s]
# eval: 100% 138/138 [00:03<00:00, 45.22it/s]
# Epoch 6: train loss :: 0.147, train acc :: 0.953, dev acc :: 0.506
# train-7: 100% 1068/1068 [02:10<00:00,  8.19it/s]
# eval: 100% 1068/1068 [00:24<00:00, 42.73it/s]
# eval: 100% 138/138 [00:03<00:00, 45.99it/s]
# Epoch 7: train loss :: 0.108, train acc :: 0.972, dev acc :: 0.489
# train-8: 100% 1068/1068 [02:10<00:00,  8.18it/s]
# eval: 100% 1068/1068 [00:25<00:00, 42.39it/s]
# eval: 100% 138/138 [00:03<00:00, 44.12it/s]
# Epoch 8: train loss :: 0.095, train acc :: 0.978, dev acc :: 0.497
# train-9: 100% 1068/1068 [02:10<00:00,  8.16it/s]
# eval: 100% 1068/1068 [00:25<00:00, 42.18it/s]
# eval: 100% 138/138 [00:03<00:00, 40.37it/s]
# Epoch 9: train loss :: 0.080, train acc :: 0.987, dev acc :: 0.498
# Evaluating on SST...
# load model from sst-classifier.pt
# load 1101 data from data/ids-sst-dev.csv
# eval: 100% 138/138 [00:03<00:00, 45.54it/s]
# DONE DEV
# eval: 100% 277/277 [00:06<00:00, 43.06it/s]
# DONE Test
# dev acc :: 0.525
# Training Sentiment Classifier on cfimdb...
# load 1707 data from data/ids-cfimdb-train.csv
# load 245 data from data/ids-cfimdb-dev.csv
# train-0: 100% 214/214 [02:04<00:00,  1.72it/s]
# eval: 100% 214/214 [00:42<00:00,  4.99it/s]
# eval: 100% 31/31 [00:06<00:00,  4.85it/s]
# save the model to cfimdb-classifier.pt
# Epoch 0: train loss :: 0.597, train acc :: 0.981, dev acc :: 0.951
# train-1: 100% 214/214 [02:04<00:00,  1.72it/s]
# eval: 100% 214/214 [00:42<00:00,  5.01it/s]
# eval: 100% 31/31 [00:06<00:00,  5.00it/s]
# save the model to cfimdb-classifier.pt
# Epoch 1: train loss :: 0.115, train acc :: 0.994, dev acc :: 0.955
# train-2: 100% 214/214 [02:04<00:00,  1.72it/s]
# eval: 100% 214/214 [00:43<00:00,  4.97it/s]
# eval: 100% 31/31 [00:06<00:00,  5.08it/s]
# Epoch 2: train loss :: 0.047, train acc :: 0.993, dev acc :: 0.931
# train-3: 100% 214/214 [02:04<00:00,  1.71it/s]
# eval: 100% 214/214 [00:43<00:00,  4.95it/s]
# eval: 100% 31/31 [00:06<00:00,  5.14it/s]
# Epoch 3: train loss :: 0.025, train acc :: 0.998, dev acc :: 0.951
# train-4: 100% 214/214 [02:03<00:00,  1.73it/s]
# eval: 100% 214/214 [00:42<00:00,  5.00it/s]
# eval: 100% 31/31 [00:06<00:00,  4.86it/s]
# Epoch 4: train loss :: 0.014, train acc :: 0.999, dev acc :: 0.951
# train-5: 100% 214/214 [02:05<00:00,  1.70it/s]
# eval: 100% 214/214 [00:42<00:00,  5.02it/s]
# eval: 100% 31/31 [00:06<00:00,  5.15it/s]
# Epoch 5: train loss :: 0.023, train acc :: 0.994, dev acc :: 0.939
# train-6: 100% 214/214 [02:04<00:00,  1.72it/s]
# eval: 100% 214/214 [00:43<00:00,  4.97it/s]
# eval: 100% 31/31 [00:06<00:00,  4.84it/s]
# save the model to cfimdb-classifier.pt
# Epoch 6: train loss :: 0.011, train acc :: 0.999, dev acc :: 0.963
# train-7: 100% 214/214 [02:04<00:00,  1.72it/s]
# eval: 100% 214/214 [00:42<00:00,  5.00it/s]
# eval: 100% 31/31 [00:06<00:00,  4.99it/s]
# Epoch 7: train loss :: 0.004, train acc :: 1.000, dev acc :: 0.955
# train-8: 100% 214/214 [02:06<00:00,  1.70it/s]
# eval: 100% 214/214 [00:42<00:00,  5.00it/s]
# eval: 100% 31/31 [00:06<00:00,  5.15it/s]
# Epoch 8: train loss :: 0.004, train acc :: 1.000, dev acc :: 0.955
# train-9: 100% 214/214 [02:04<00:00,  1.72it/s]
# eval: 100% 214/214 [00:42<00:00,  5.00it/s]
# eval: 100% 31/31 [00:06<00:00,  4.88it/s]
# Epoch 9: train loss :: 0.002, train acc :: 1.000, dev acc :: 0.947
# Evaluating on cfimdb...
# load model from cfimdb-classifier.pt
# load 245 data from data/ids-cfimdb-dev.csv
# eval: 100% 31/31 [00:06<00:00,  4.92it/s]
# DONE DEV
# eval: 100% 61/61 [00:12<00:00,  4.91it/s]
# DONE Test
# dev acc :: 0.963
